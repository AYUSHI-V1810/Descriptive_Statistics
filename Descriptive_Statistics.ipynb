# %% [markdown]
# # **Descriptive** **Statistics**

# %% [markdown]
# **ASSIGNMENT**

# %% [markdown]
#  **EASY LEVEL**

# %% [markdown]
# **Q1: Understanding Central Tendency (Easy)**
#
#   A bakery tracks the daily sales of muffins (in dozens) over a
#   week: [10, 12, 11, 15, 14, 13, 12].
# What is the most representative value of their weekly sales, and why?

# %% [markdown]
# **ANSWER**- FIRSTLY, Arranged the daily sales in ascending order.
#         [10,11,12,12,13,14,15] like this.
#         second we want to find most representative values for their weakly sales, through median or average.
#                    average be = 12.43 and
#                    median be = 12 ,
#          [Both the Median and the Mode are exactly 12. This indicates that 12 is the most common and central result for the week.]
#
#   ​Conclusion: If the bakery needs to decide how many muffins to prep for a standard day based on this week, 12 dozen is the safest and most accurate representation of their  daily sales.

# %% [markdown]
# Q2 Mean in Real Life (Easy)
# A teacher records the marks of her students in a short quiz: [12, 15, 14, 16, 18, 20, 19].
# What is the mean score, and what does it tell us about the class performance?

# %% [markdown]
# ANSWER -  Arranged in ascending order [12, 14, 15, 16, 18, 19, 20].
#           the mean or average score of the students in short quiz be
#           [12+14+15+16+18+19+20]/7 = 16.28
#           it represented avarage performance in class.

# %% [markdown]
# **Q3  Mode in Real Life (Easy)**
# A store records the shoe sizes sold in one day: [7, 8, 9, 8, 8, 10, 7, 9].
# What is the mode, and why is this information useful for the store manager?

# %% [markdown]
# **ANSWER**- [7,7,8,8,8,9,9,10]
#          MODE shows the highest frequency.
#          shoes size - 8 (highest frequency)
#          so mode will be 8.
#          This information useful for the store manager because it tells which number of size available in stoks and which size is most demanding or popular in market.

# %% [markdown]
# **Medium LEVEL**

# %% [markdown]
# **Q4 Median in Real Life (Medium)**
# A car dealer notes the prices of used cars: [$8000,$9,500, $10,200, $11,000, $50,000]
# Why is the median a better measure than the mean in this case? Calculate the median.

# %% [markdown]
# ANSWER-  because their is outliar ($50,000). if we find mean instead of median the average (mean) be easily distorted by extreme values and making it unreliable. so we find median .
# median price of the car be 50,000 USD .

# %% [markdown]
# **Q5  Dispersion Introduction (Medium)**
#
# A student times how long it takes to finish a puzzle each day: [25, 30, 27, 35, 40].
#  What does the range tell us about the variation in the student’s puzzle-solving time?

# %% [markdown]
# **ANSWER** - [25,27,30,35,40]                                      The range DEFINED as the maximum difference between the longest and shortest times the student took to finish the puzzle.
# MAX TIME BE 40  AND MIN TIME BE 25 .
# RANGE - [40-25] = 15.
# it indicates the student best and wrost performance time .

# %% [markdown]
# **Q6 Range in Action (Medium)**
# A farmer records the weekly weight of harvested apples (kg): [100, 105, 98, 110, 120].
# Find the range. How can this help the farmer in planning his packaging?

# %% [markdown]
# **ANSWER -**  Arranged the apples(KG) in assending order
#               **[98,100,105,110,120]     **
#              [RANGE = Highest weight - lowest weight]
#              RANGE   =    [120-98] = 22KG
#              It helps customer to sorting apples in sizes and packing materials to make safe and profitable.

# %% [markdown]
# **Q7 Variance for Decision-Making (Medium)**
# Two delivery companies track delivery delays (in minutes).
#
# Company A: variance = 6
#
# Company B: variance = 15
#  Which company is more consistent, and why?

# %% [markdown]
# **ANSWER -**  VARIENCE actually measures the DISPERSION of data points from average.
# COMPANY A is more consistent (less volatile).

# %% [markdown]
# **Hard Level**

# %% [markdown]
# **Q8: Standard Deviation in Context (Hard)**
# A finance student compares the daily price fluctuations of two cryptocurrencies.
#
# Coin A: standard deviation = $30
#
# Coin B: standard deviation = $120
#  Which coin is riskier to invest in, and why?

# %% [markdown]
# **ANSWER-**   Coin B is riskier to invest in because the movement or
#               fluctuation is larger according to price.

# %% [markdown]
# **Q9: Combining Measures (Hard)**
# A family records their monthly electricity usage (in kWh): [400, 420, 390, 450, 410].
#   Find the mean and standard deviation. What do these values together tell you about the family’s energy use
# pattern?

# %% [markdown]
# **ANSWER -**  Arranged monthly usage electricity(KWH) in ASCENDING ORDER -
#               [390,400,410,420,450]
#               MEAN - 2070/5 = 414(KWH)
#               STANDARD DEVIATION -
#               (390-414)=(-24)*(-24) = 576
#               (400-414)=(-14)*(-14) = 196
#               (410-414)=(-4)*(-4)  =16
#               (420-414)= (6)  *(6) =36
#               (450-414)= (36)*(36) =1296
#            Sum = 576+196+16+36+1296 = 2120
#            now =STDEV.P(C3:G3) = 20.59126028 (KWH)
#               =STDEV.S(C3:G3)  = 23.02172887 (KWH)
#     High-intensity but remarkably consistent energy consumption, averaging 414 kWh with minimal daily variance.
#     MEAN

# %% [markdown]
# **Q10: Practical Application (Hard)**
# A basketball player’s points in 8 games are recorded: [15, 18, 20, 22, 25, 17, 19, 21].
# Find the mean, median, mode, range, and standard deviation. What insights can these measures provide
# about the player’s scoring performance?

# %% [markdown]
# **ANSWER -**  Mean value is 19.625 and
#               Median value is 19.5
#  there is no mode value in this data BECAUSE all values are unique ,
#   the range is [25-15] = 10
#   the standard deviation is 3.11 it showing the consistency of scoring.
#  INSIGHTS - A highly consistent and symmetrical scorer who reliably contributes approximately 20 points per game with very little fluctuation in performance.
